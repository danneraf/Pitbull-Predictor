# %% [markdown]
# # mr worldwide

# %% [markdown]
# https://lyricsgenius.readthedocs.io/en/master/

# %% [markdown]
# https://pypi.org/project/lyricsgenius/

# %% [markdown]
# Get your own API key (token) [here](https://docs.genius.com/#/getting-started-h1)

# %%
# !pip install lyricsgenius

# %%
import json
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# When running the cell with max_songs set to 1000, it maxed at 672, so I changed the parameter to 672.

# %%
import lyricsgenius
from lyricsgenius import Genius

genius = lyricsgenius.Genius('token') # replace token 

artist = genius.search_artist('Pitbull', max_songs=672, sort='title', include_features=True)
print(artist.songs) 
artist.save_lyrics()
# Out:
# Searching for songs by Pitbull...
#
# Song 1: "11:59"
# Song 2: "305 Anthem"
# Song 3: "305 In Paris"
# Song 4: "305 Til I Die"
# Song 5: "3bkzo RIMIX"
# Song 6: "3 Letters"
# Song 7: "3 to Tango"
# Song 8: "Across the World"
# "Africa" is not valid. Skipping.
# Song 9: "Ah Leke"
# Song 10: "Ai Se Eu Te Pego (If I Get Ya)"
# Song 11: "Aleluya"
# Song 12: "A Little Story (Intro)"
# Song 13: "All 4 Sale"
# Song 14: "All About You"
# Song 15: "All Day"
# Song 16: "All Night"
# Song 17: "All Night Long (Remix)"
# Song 18: "All of the Girls"
# Song 19: "All the Things"
# Song 20: "Alright"
# Song 21: "Alright (Intro)"
# "Amanda Diva Skit" is not valid. Skipping.
# Song 22: "America"
# Song 23: "American War"
# Song 24: "A Milli (Freestyle)"
# Song 25: "Amore"
# Song 26: "Amorosa"
# Song 27: "Amor (Spanglish Remix)"
# Song 28: "Angels Cry (Jump Smokers Remix)"
# Song 29: "Another Round"
# Song 30: "Armada Latina"
# Song 31: "Armando (Intro)"
# Song 32: "Asesina"
# Song 33: "Ay Ay Ay"
# ...

# %% [markdown]
# Some songs listed (such as Song 134: "Crzfawkz holla at me verse ( TEST ONLY )") may not be valid or may be repeats.
